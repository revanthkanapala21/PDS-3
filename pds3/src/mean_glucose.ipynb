# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
np.random.seed(42)

# %%
df_diabetes = pd.read_csv('/Users/revanthkumarkanapala/Desktop/pds3/raw_data/diabetes.csv')

# %%
# Taking a random sample of 25 observations
sample_size = 25
sample = df_diabetes.sample(sample_size)

# Calculating mean and highest Glucose values for the sample
sample_mean_glucose = sample['Glucose'].mean()
sample_highest_glucose = sample['Glucose'].max()

# Calculating mean and highest Glucose values for the entire population
population_mean_glucose = df_diabetes['Glucose'].mean()
population_highest_glucose = df_diabetes['Glucose'].max()

# %%
# Creating a bar chart for comparison
labels = ['Sample Mean', 'Sample Highest', 'Population Mean', 'Population Highest']
values = [sample_mean_glucose, sample_highest_glucose, population_mean_glucose, population_highest_glucose]

fig, ax = plt.subplots()
bars = ax.bar(labels, values, color=['blue', 'green', 'orange', 'red'])

# Displaying the exact numbers on the bars
for bar, value in zip(bars, values):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(value, 2), ha='center', va='bottom')

plt.ylabel('Glucose Values')
results_dir = '/Users/revanthkumarkanapala/Desktop/pds3/results'
plt.savefig(os.path.join(results_dir, 'mean_comparison_plot.png'))
plt.title('Comparison of Glucose Statistics between Sample and Population')
# Out:
# Text(0.5, 1.0, 'Comparison of Glucose Statistics between Sample and Population')
